# %% [markdown]
# # **Autism EDA**

# %% [markdown]
# ## **Exploratory Data Analysis (EDA)**

# %% [markdown]
# #### Loading and Displaying data

# %%
import pandas as pd

# Not limiting the column number when displaying dataframe
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("/Autism_Data.arff", sep = r',', skipinitialspace = True)

df = df.rename(columns = {"austim": "autism"})
df = df.replace("yes", 1)
df = df.replace("no", 0)
df = df.replace("f", 1)
df = df.replace("m", 0)

df.head()
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 4         1         0         0         0         0         0         0
#
#    A8_Score  A9_Score  A10_Score age  gender       ethnicity  jundice  autism  \
# 0         1         0          0  26       1  White-European        0       0
# 1         1         0          1  24       0          Latino        0       1
# 2         1         1          1  27       0          Latino        1       1
# 3         1         0          1  35       1  White-European        0       1
# 4         1         0          0  40       1               ?        0       0
#
# ...

# %%
df.tail()
# Out:
#      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 699         0         1         0         1         1         0         1
# 700         1         0         0         0         0         0         0
# 701         1         0         1         1         1         0         1
# 702         1         0         0         1         1         0         1
# 703         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score age  gender       ethnicity  jundice  \
# 699         1         1          1  25       1  White-European        0
# 700         1         0          1  34       0        Hispanic        0
# 701         1         0          1  24       1               ?        0
# 702         0         1          1  35       0   'South Asian'        0
# 703         1         1          1  26       1  White-European        0
#
#      autism contry_of_res  used_app_before  result       age_desc relation  \
# ...

# %% [markdown]
# #### Number of columns

# %%
print(df.columns)
# Out:
# Index(['A1_Score', 'A2_Score', 'A3_Score', 'A4_Score', 'A5_Score', 'A6_Score',
#        'A7_Score', 'A8_Score', 'A9_Score', 'A10_Score', 'age', 'gender',
#        'ethnicity', 'jundice', 'autism', 'contry_of_res', 'used_app_before',
#        'result', 'age_desc', 'relation', 'Class/ASD'],
#       dtype='object')

# %% [markdown]
# #### Shape of the train dataset

# %%
rows = df.shape[0]
cols = df.shape[1]

print("Before cleaning, there are " + str(rows) + " rows and " + str(cols) + " columns in this dataframe.")
# Out:
# Before cleaning, there are 704 rows and 21 columns in this dataframe.

# %% [markdown]
# #### Any duplicates?

# %%
dupRows = df.duplicated().sum()
print("There are " + str(dupRows) + " duplicated rows in the dataframe.")
# Out:
# There are 5 duplicated rows in the dataframe.

# %% [markdown]
# #### Any null values? If yes, how many in which column?

# %%
df.isnull().sum()
# Out:
# A1_Score           0
# A2_Score           0
# A3_Score           0
# A4_Score           0
# A5_Score           0
# A6_Score           0
# A7_Score           0
# A8_Score           0
# A9_Score           0
# A10_Score          0
# age                0
# gender             0
# ethnicity          0
# jundice            0
# autism             0
# contry_of_res      0
# used_app_before    0
# result             0
# age_desc           0
# relation           0
# Class/ASD          0
# dtype: int64

# %% [markdown]
# There are no null values in the dataframe.

# %% [markdown]
# #### Sum of unique values per column

# %%
df.nunique()
# Out:
# A1_Score            2
# A2_Score            2
# A3_Score            2
# A4_Score            2
# A5_Score            2
# A6_Score            2
# A7_Score            2
# A8_Score            2
# A9_Score            2
# A10_Score           2
# age                47
# gender              2
# ethnicity          12
# jundice             2
# autism              2
# contry_of_res      67
# used_app_before     2
# result             11
# age_desc            1
# relation            6
# Class/ASD           2
# dtype: int64

# %% [markdown]
# #### Data types of the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704 entries, 0 to 703
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   A1_Score         704 non-null    int64
#  1   A2_Score         704 non-null    int64
#  2   A3_Score         704 non-null    int64
#  3   A4_Score         704 non-null    int64
#  4   A5_Score         704 non-null    int64
#  5   A6_Score         704 non-null    int64
#  6   A7_Score         704 non-null    int64
#  7   A8_Score         704 non-null    int64
#  8   A9_Score         704 non-null    int64
#  9   A10_Score        704 non-null    int64
#  10  age              704 non-null    object
#  11  gender           704 non-null    int64
#  12  ethnicity        704 non-null    object
#  13  jundice          704 non-null    int64
#  14  autism           704 non-null    int64
#  15  contry_of_res    704 non-null    object
#  16  used_app_before  704 non-null    int64
# ...

# %% [markdown]
# #### Statistics for each column

# %%
df.describe()
# Out:
#          A1_Score    A2_Score    A3_Score    A4_Score    A5_Score    A6_Score  \
# count  704.000000  704.000000  704.000000  704.000000  704.000000  704.000000
# mean     0.721591    0.453125    0.457386    0.495739    0.498580    0.284091
# std      0.448535    0.498152    0.498535    0.500337    0.500353    0.451301
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      1.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          A7_Score    A8_Score    A9_Score   A10_Score      gender     jundice  \
# count  704.000000  704.000000  704.000000  704.000000  704.000000  704.000000
# mean     0.417614    0.649148    0.323864    0.573864    0.478693    0.098011
# ...

# %% [markdown]
# #### How much memory does each column need (in bytes)?

# %%
df.memory_usage()
# Out:
# Index               128
# A1_Score           5632
# A2_Score           5632
# A3_Score           5632
# A4_Score           5632
# A5_Score           5632
# A6_Score           5632
# A7_Score           5632
# A8_Score           5632
# A9_Score           5632
# A10_Score          5632
# age                5632
# gender             5632
# ethnicity          5632
# jundice            5632
# autism             5632
# contry_of_res      5632
# used_app_before    5632
# result             5632
# age_desc           5632
# relation           5632
# Class/ASD          5632
# dtype: int64

# %% [markdown]
# #### How much do the columns correlate with each other?

# %% [markdown]
# The **corr()**-function is used to find the pairwise correlation of all columns in the dataframe. Any missing values are automatically excluded. For any non-numeric data type columns in the dataframe, it is ignored. This function comes in handy while we doing the Feature Selection by observing the correlation between features and target variable or between variables.

# %%
df.corr()
# Out:
#                  A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  \
# A1_Score         1.000000  0.011539  0.074096  0.127814  0.169369  0.110199
# A2_Score         0.011539  1.000000  0.223921  0.158998  0.153821  0.185864
# A3_Score         0.074096  0.223921  1.000000  0.412722  0.264927  0.268846
# A4_Score         0.127814  0.158998  0.412722  1.000000  0.306806  0.295152
# A5_Score         0.169369  0.153821  0.264927  0.306806  1.000000  0.392354
# A6_Score         0.110199  0.185864  0.268846  0.295152  0.392354  1.000000
# A7_Score         0.217538 -0.041768  0.078216  0.151236  0.238589  0.175489
# A8_Score         0.147640  0.035408  0.017771  0.008617  0.102086  0.100123
# A9_Score         0.145452  0.205421  0.315113  0.327673  0.396582  0.479422
# A10_Score        0.118413  0.068883  0.168454  0.210968  0.267561  0.294435
# gender           0.075011  0.047393 -0.000795  0.056508  0.039688  0.083615
# ...

# %% [markdown]
# #### Visualizing the correlation table above

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlations = df.corr()

plt.figure(figsize = (16, 12))
plt.title("Heatmap displaying the correlations between all columns", fontsize = 20)
sns.heatmap(correlations, annot = True, cmap = "mako")

# %% [markdown]
# #### How much are the columns correlation with our target/pred column **autism**?

# %%
autcorr = df.corr()["autism"]
autcorr = pd.DataFrame(autcorr)
autcorr
# Out:
#                    autism
# A1_Score         0.097630
# A2_Score         0.074555
# A3_Score         0.113697
# A4_Score         0.193820
# A5_Score         0.090009
# A6_Score         0.114048
# A7_Score        -0.008610
# A8_Score         0.034845
# A9_Score         0.167644
# A10_Score        0.117969
# gender           0.088477
# jundice          0.157793
# autism           1.000000
# used_app_before  0.014682
# result           0.192033

# %%
# %matplotlib inline

plt.figure(figsize = (16, 12))
plt.title("Correlations between input columns and target column 'autism'", fontsize = 20)
plt.xlabel("Columns", fontsize = 16)
plt.ylabel("Correlation factor", fontsize = 16)
plt.plot(autcorr, color = "magenta", linestyle = "", marker = "X")
plt.show()

# %%
pd.crosstab(df["age"], df["autism"])
# Out:
# autism   0  1
# age
# 17      15  3
# 18      28  3
# 19      34  1
# 20      45  1
# 21      46  3
# 22      36  1
# 23      35  2
# 24      30  4
# 25      25  2
# 26      26  2
# 27      28  3
# 28      22  2
# 29      26  1
# 30      24  6
# 31      17  4
# 32      15  3
# 33      12  4
# 34      11  1
# 35      10  7
# 36       9  4
# 37      13  4
# 38       9  3
# 383      1  0
# 39       3  4
# 40      11  5
# 41       2  1
# 42      12  3
# 43      11  0
# 44       7  3
# 45       3  1
# 46       3  3
# 47       7  1
# 48       3  1
# 49       3  0
# 50       5  0
# 51       1  0
# 52       5  0
# 53       5  1
# 54       1  1
# 55       5  1
# 56       2  0
# 58       2  0
# 59       1  0
# 60       0  1
# 61       1  1
# 64       1  0
# ?        2  0

# %%
ct = pd.crosstab(df["age"], df["autism"]) 

plt.figure(figsize = (16, 12))
plt.title("Crosstab showing how many autism patients have what age", fontsize = 20)
sns.heatmap(ct, cmap = "YlGnBu", annot = True, cbar = True, fmt = "g")

# %% [markdown]
# Apparantly, most people appearing in these statistics were younger people. However, among those who were diagnosed with autism, most were middleaged (early 20s to mid 40s) with very few people younger or older than that.

# %% [markdown]
# #### How many people of what ethnicity were diagnosed?

# %%
pd.crosstab(df["ethnicity"], df["autism"])
# Out:
# autism               0   1
# ethnicity
# 'Middle Eastern '   83   9
# 'South Asian'       34   2
# ?                   89   6
# Asian              118   5
# Black               38   5
# Hispanic            12   1
# Latino              12   8
# Others              28   2
# Pasifika            10   2
# Turkish              5   1
# White-European     183  50
# others               1   0

# %%
ct = pd.crosstab(df["ethnicity"], df["autism"]) 

plt.figure(figsize = (16, 12))
plt.title("Crosstab showing how many autism diagnosis come from which ethnicity", fontsize = 20)
sns.heatmap(ct, cmap = "RdPu", annot = True, cbar = True, fmt = "g")

# %%
pd.set_option("display.max_columns", None)

# %%
from sklearn import preprocessing

df = pd.read_csv("/Autism_Data.arff", sep = r',', skipinitialspace = True)

df = df.fillna(0)
df = df.drop(["A7_Score"], axis = 1)
df = df.drop(["used_app_before"], axis = 1)

df = df.rename(columns = {"austim": "autism", "contry_of_res": "country"})
df = df.replace("yes", 1)
df = df.replace("no", 0)
df = df.replace("f", 1)
df = df.replace("m", 0)
df = df.replace("YES", 1)
df = df.replace("NO", 0)
df = df.replace("?", 0)

# Typecasting
df["ethnicity"] = df["ethnicity"].astype(str)
df["country"] = df["country"].astype(str)
df["age_desc"] = df["age_desc"].astype(str)
df["relation"] = df["relation"].astype(str)

# Initializing Encoder
number = preprocessing.LabelEncoder()

# Encoding
df["ethnicity"] = number.fit_transform(df["ethnicity"])
df["country"] = number.fit_transform(df["country"])
df["age_desc"] = number.fit_transform(df["age_desc"])
df["relation"] = number.fit_transform(df["relation"])

df.head()
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A8_Score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         1
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 4         1         0         0         0         0         0         1
#
#    A9_Score  A10_Score age  gender  ethnicity  jundice  autism  country  \
# 0         0          0  26       1         10        0       0       10
# 1         0          1  24       0          6        0       1       25
# 2         1          1  27       0          6        1       1       61
# 3         0          1  35       1         10        0       1       10
# 4         0          0  40       1          2        0       0       32
#
#    result  age_desc  relation  Class/ASD
# 0       6         0         5          0
# ...

# %%
df.shape
# Out:
# (704, 19)

# %%
X = df.drop(["autism"], axis = 1).values
y = df["autism"].values


from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0, test_size = 0.25)

# %% [markdown]
# #### **Scaling data**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(solver = "liblinear")
model.fit(X_train, y_train)

print(model.score(X_test, y_test))
# Out:
# 0.8977272727272727

# %% [markdown]
# #### **Multinomial Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(multi_class = "multinomial", solver = "newton-cg")
model.fit(X_train, y_train)

print(model.score(X_test, y_test))
# Out:
# 0.8920454545454546

# %% [markdown]
# #### **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(criterion = "entropy", max_depth = 5)
model.fit(X_train, y_train)

print(model.score(X_test, y_test))
# Out:
# 0.8636363636363636

# %% [markdown]
# #### **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(criterion = "entropy")
model.fit(X_train, y_train)

model.score(X_test, y_test)
# Out:
# 0.8863636363636364

# %% [markdown]
# #### **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors = 15)
model.fit(X_train, y_train)

print(model.score(X_test, y_test))
# Out:
# 0.9090909090909091

# %% [markdown]
# #### **SVM**

# %%
from sklearn.svm import SVC

model = SVC(kernel = "linear", gamma = 0.1, C = 0.1)
model.fit(X_train, y_train)

print(model.score(X_test, y_test))
# Out:
# 0.9090909090909091
